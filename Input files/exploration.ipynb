# %%
import pandas as pd

# %%
df = pd.read_json('qa_data.json',lines = True)

# %%
df
# Out:
#                                               knowledge  \
# 0     Arthur's Magazine (1844–1846) was an American ...
# 1     The Oberoi family is an Indian family that is ...
# 2     Allison Beth "Allie" Goertz (born March 2, 199...
# 3     Margaret "Peggy" Seeger (born June 17, 1935) i...
# 4      It is a hygroscopic solid that is highly solu...
# ...                                                 ...
# 9995  James Norman Hall (22 April 1887 – 5 July 1951...
# 9996  Love in the Time of Money is a 2002 American r...
# 9997  Ape Escape, known in Japan as Excited Saru Get...
# 9998   An accomplished full-forward, Capper kicked 3...
# 9999   The title is a corruption of "melodrama", tho...
#
#                                                question  \
# 0     Which magazine was started first Arthur's Maga...
# 1     The Oberoi family is part of a hotel company t...
# 2     Musician and satirist Allie Goertz wrote a son...
# 3       What nationality was James Henry Miller's wife?
# ...

# %%
count = df['question'].str.split().str.len()
count.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\willa\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\willa\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\willa\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'question'
#
# The above exception was the direct cause of the following exception:
#
# ...
